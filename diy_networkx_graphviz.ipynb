# %% [markdown]
# 使用 networkx 与 pygraphviz 绘制图形
# ---------------------------------
#
# Documentation: ../networkx-documentation/reference/generated/networkx.drawing.nx_pylab.draw_networkx.html#networkx.drawing.nx_pylab.draw_networkx
#
# Also see the NetworkX drawing examples at http://networkx.lanl.gov/gallery.html

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import networkx as nx
G=nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G,pos=nx.spring_layout(G))

# %%
import networkx as nx
# 此部分代码需要安装 pygraphviz
#CC=/usr/bin/gcc
#pip install pygraphviz
###
import matplotlib.pyplot as plt

G = nx.DiGraph()

G.add_node("ROOT")

for i in xrange(5):
    G.add_node("Child_%i" % i)
    G.add_node("Grandchild_%i" % i)
    G.add_node("Greatgrandchild_%i" % i)

    G.add_edge("ROOT", "Child_%i" % i)
    G.add_edge("Child_%i" % i, "Grandchild_%i" % i)
    G.add_edge("Grandchild_%i" % i, "Greatgrandchild_%i" % i)

# write dot file to use with graphviz
# run "dot -Tpng test.dot >test.png"
nx.write_dot(G,'diy_networkx_graphviz.output.txt')  #将图结构输出到文件 .dot 格式

# same layout using matplotlib with no labels
plt.title("draw_networkx")
pos=nx.graphviz_layout(G,prog='dot')  #使用 pygraphviz 获取图形坐标 
nx.draw(G,pos,with_labels=False,arrows=False)
plt.show()
